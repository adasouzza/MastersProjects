# %% [markdown]
# # ANÁLISE - Busca Cega

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# Inserindo algoritmos e tempos decorridos das análises
algoritmos = ['GBFS', 'DFS', 'BFS']
tempos = [0.054617881774902344, 0.961374044418335, 14.441920042037964,]

# %%
# Configurar gráfico de análise
plt.rcParams['figure.figsize'] = (11,7)
plt.style.use('ggplot')
plt.title('Análise - Busca Cega Puzzle')
plt.xlabel('Algoritmos')
plt.ylabel('Tempo decorrido')
plt.plot(algoritmos, tempos)
plt.show()

# %% [markdown]
# # Análise - Busca Heurística Puzzle (A*)
#
#
# * DIREITA, BAIXO, ESQUERDA, BAIXO, DIREITA, DIREITA, CIMA, ESQUERDA, ESQUERDA, BAIXO, DIREITA, CIMA, CIMA, DIREITA, BAIXO, BAIXO, ESQUERDA, ESQUERDA, CIMA, DIREITA, DIREITA, BAIXO
# * o CUSTO do CAMINHO é:  22
# * Contador de nós gerados: 5887
# * Contador de nós expandidos: 2194
#
#
# * DIREITA, BAIXO, ESQUERDA, BAIXO, DIREITA, DIREITA, CIMA, ESQUERDA, ESQUERDA, BAIXO, DIREITA, CIMA, CIMA, DIREITA, BAIXO, BAIXO, ESQUERDA, ESQUERDA, CIMA, DIREITA, DIREITA, BAIXO
# * o CUSTO do CAMINHO é:  22
# * Contador de nós gerados: 38208
# * Contador de nós expandidos: 14067

# %%
nosGerados = {'h2': 5887, 'h1': 38208}
nomesgerados = list(nosGerados.keys())
valoresGerados = list(nosGerados.values())

nosExpandidos = {'h2': 2194, 'h1': 14067}
nomesExpandidos = list(nosExpandidos.keys())
valoresExpandidos = list(nosExpandidos.values())

caminho = {'h2': 22, 'h1': 22}
nomesCaminhos = list(caminho.keys())
valoresCaminhos = list(caminho.values())

fig, axs = plt.subplots(1, 2, figsize=(11, 5), sharey=True)
axs[0].bar(names, values)
axs[1].bar(nomesExpandidos, valoresExpandidos)
fig.suptitle('Análise A*')
# Out:
# Text(0.5, 0.98, 'Análise A*')
